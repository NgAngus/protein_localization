# %%
# !ls ../data/raw
# Out:
# field_descriptions.txt   protein_interactions.csv test.csv
# label_legend.csv         sample_submission.csv    train.csv

# %%
import pandas as pd

# %%
LOCAL = True
if LOCAL:
    fpath = "../data/raw/"

# %%
df = pd.read_csv(f"{fpath}train.csv")
# Out:
# /Users/angus/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (444) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#      P239476  Non-Essential  No No.1 No.2 No.3 No.4 No.5 No.6 No.7  ...  \
# 0    P234427  Non-Essential  No   No   No   No   No   No   No   No  ...
# 1    P234429  Non-Essential  No   No   No  Yes   No   No   No   No  ...
# 2    P234430  Non-Essential  No   No   No   No   No   No   No   No  ...
# 3    P239467      Essential  No   No   No   No   No   No   No   No  ...
# 4    P234437              ?  No   No   No   No   No   No   No   No  ...
# ..       ...            ...  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 856  P235892  Non-Essential  No   No   No   No   No   No   No   No  ...
# 857  P235906  Non-Essential  No   No   No   No   No   No   No   No  ...
# 858  P235897  Non-Essential  No   No   No   No   No   No   No   No  ...
# 859  P235905      Essential  No   No   No   No   No   No   No   No  ...
# 860  P235899      Essential  No   No   No   No   No   No   No   No  ...
#
#     No.1307 No.1308 Yes.3 No.1309 No.1310 Yes.4 No.1311 No.1312  \
# ...
